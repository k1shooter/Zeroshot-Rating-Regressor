# %%
import pandas as pd
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
movie=pd.read_csv('/content/drive/MyDrive/deeplearning/Movie Review And Rating.csv')

# %%
movie
# Out:
#          ID                    Movie  Year            Genres  \
# 0    100001  Spider-Man: No Way Home  2021  Action/Adventure
# 1    100002  Spider-Man: No Way Home  2021  Action/Adventure
# 2    100003  Spider-Man: No Way Home  2021  Action/Adventure
# 3    100004  Spider-Man: No Way Home  2021  Action/Adventure
# 4    100005  Spider-Man: No Way Home  2021  Action/Adventure
# ..      ...                      ...   ...               ...
# 995  100996                  Snowden  2016    Thriller/Drama
# 996  100997                  Snowden  2016    Thriller/Drama
# 997  100998                  Snowden  2016    Thriller/Drama
# 998  100999                  Snowden  2016    Thriller/Drama
# 999  101000                  Snowden  2016    Thriller/Drama
#
#                                                 Review  Rating
# 0    This is by far the best Spider-Man or even Mar...       5
# 1    Coming from someone who doesn’t like the previ...       5
# ...

# %%
moviedataset=movie.drop(['ID','Movie','Year'],axis=1)

# %%
moviedataset
# Out:
#                Genres                                             Review  \
# 0    Action/Adventure  This is by far the best Spider-Man or even Mar...
# 1    Action/Adventure  Coming from someone who doesn’t like the previ...
# 2    Action/Adventure  Marvel has outdone themselves. This is the qui...
# 3    Action/Adventure  Saw this #FDFS at 5am\nYou beauty Spider-Man\n...
# 4    Action/Adventure  Best in the Spiderman line, and it takes top s...
# ..                ...                                                ...
# 995    Thriller/Drama  it is insulting and the worse movie i have eve...
# 996    Thriller/Drama  So one sided, so agenda driven by the left it’...
# 997    Thriller/Drama                    It’s a propaganda, not a movie.
# 998    Thriller/Drama                                            Boring!
# 999    Thriller/Drama  Intelligent, brilliant, emotional, touching, s...
#
#      Rating
# 0         5
# 1         5
# 2         5
# 3         5
# 4         5
# ...

# %%
moviedataset['Genres'] = moviedataset['Genres'].str.replace('/', ' and ')
moviedataset['Genres'] = "A movie in the genre of "+moviedataset['Genres']
moviedataset['Rating'] = moviedataset['Rating']*2

# %%
moviedataset
# Out:
#                                            Genres  \
# 0    A movie in the genre of Action and Adventure
# 1    A movie in the genre of Action and Adventure
# 2    A movie in the genre of Action and Adventure
# 3    A movie in the genre of Action and Adventure
# 4    A movie in the genre of Action and Adventure
# ..                                            ...
# 995    A movie in the genre of Thriller and Drama
# 996    A movie in the genre of Thriller and Drama
# 997    A movie in the genre of Thriller and Drama
# 998    A movie in the genre of Thriller and Drama
# 999    A movie in the genre of Thriller and Drama
#
#                                                 Review  Rating
# 0    This is by far the best Spider-Man or even Mar...      10
# 1    Coming from someone who doesn’t like the previ...      10
# 2    Marvel has outdone themselves. This is the qui...      10
# 3    Saw this #FDFS at 5am\nYou beauty Spider-Man\n...      10
# ...

# %%
moviedataset.rename(columns={'Genres':'Category'},inplace=True)

# %%
moviedataset.dropna(inplace=True)

# %%
moviedataset
# Out:
#                                          Category  \
# 0    A movie in the genre of Action and Adventure
# 1    A movie in the genre of Action and Adventure
# 2    A movie in the genre of Action and Adventure
# 3    A movie in the genre of Action and Adventure
# 4    A movie in the genre of Action and Adventure
# ..                                            ...
# 995    A movie in the genre of Thriller and Drama
# 996    A movie in the genre of Thriller and Drama
# 997    A movie in the genre of Thriller and Drama
# 998    A movie in the genre of Thriller and Drama
# 999    A movie in the genre of Thriller and Drama
#
#                                                 Review  Rating
# 0    This is by far the best Spider-Man or even Mar...      10
# 1    Coming from someone who doesn’t like the previ...      10
# 2    Marvel has outdone themselves. This is the qui...      10
# 3    Saw this #FDFS at 5am\nYou beauty Spider-Man\n...      10
# ...

# %%
moviedataset.to_csv('/content/drive/MyDrive/deeplearning/processed_rating/moviedataset.csv')

# %%
album=pd.read_csv('/content/drive/MyDrive/deeplearning/datasets_for_rating/music_album_reviews.csv')

# %%
album
# Out:
#                                                   Review  Rating
# 0      i think i actually under-rate ok computer if a...     5.0
# 1      i get why radiohead rub a lot of people the wr...     5.0
# 2      i would like to think i am good about not lett...     4.5
# 3      there are radiohead devotees like there were o...     4.0
# 4      i wrote a shining excellent review for this al...     5.0
# ...                                                  ...     ...
# 80266  my favorites here are the steamy lady cab driv...     3.0
# 80267  prince would have been well-advised to make th...     4.5
# 80268  you know you cannot say its not a classic beca...     3.5
# 80269                          the classic prince album.     5.0
# 80270  i do not like funk and i do not like prince. t...     1.0
#
# [80271 rows x 2 columns]

# %%
albumdata=album

# %%
albumdata['Rating']=albumdata['Rating']*2
albumdata['Category']="Music album"

# %%
albumdata.dropna(inplace=True)

# %%
albumdata
# Out:
#                                                   Review  Rating     Category
# 0      i think i actually under-rate ok computer if a...    10.0  Music album
# 1      i get why radiohead rub a lot of people the wr...    10.0  Music album
# 2      i would like to think i am good about not lett...     9.0  Music album
# 3      there are radiohead devotees like there were o...     8.0  Music album
# 4      i wrote a shining excellent review for this al...    10.0  Music album
# ...                                                  ...     ...          ...
# 80266  my favorites here are the steamy lady cab driv...     6.0  Music album
# 80267  prince would have been well-advised to make th...     9.0  Music album
# 80268  you know you cannot say its not a classic beca...     7.0  Music album
# 80269                          the classic prince album.    10.0  Music album
# 80270  i do not like funk and i do not like prince. t...     2.0  Music album
#
# [78162 rows x 3 columns]

# %%
albumdata.to_csv('/content/drive/MyDrive/deeplearning/processed_rating/albumdata.csv')

# %%
amazon=pd.read_csv('/content/drive/MyDrive/deeplearning/datasets_for_rating/Amazon Review Data Web Scrapping - Amazon Review Data Web Scrapping.csv')

# %%
amazon
# Out:
#        Unique_ID Category                           Review_Header  \
# 0         136040  smartTv                                Nice one
# 1         134236   mobile  Huge battery life with amazing display
# 2         113945    books                              Four Stars
# 3         168076  smartTv                            Nice quality
# 4         157302    books                               Nice book
# ...          ...      ...                                     ...
# 60884     148315  smartTv                                    Good
# 60885     162092  smartTv                              Five Stars
# 60886     164387   mobile                           Best in prise
# 60887     133063  smartTv                           Not gud pbone
# 60888     167823   mobile                           Not recommend
#
#                                              Review_text  Rating Own_Rating
# 0                                             I liked it       5   Positive
# ...

# %%
amazondata1=amazon[['Category','Review_text','Rating']]
amazondata2=amazon[['Category','Review_Header','Rating']]

# %%
amazondata1['Rating']=amazondata1['Rating']*2
amazondata2['Rating']=amazondata2['Rating']*2
# Out:
# <ipython-input-48-8f0a9a73f914>:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   amazondata1['Rating']=amazondata1['Rating']*2
# <ipython-input-48-8f0a9a73f914>:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   amazondata2['Rating']=amazondata2['Rating']*2

# %%
amazondata1.rename(columns={'Review_text':'Review'},inplace=True)
amazondata2.rename(columns={'Review_Header':'Review'},inplace=True)
# Out:
# <ipython-input-49-4c5f28534bb9>:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   amazondata1.rename(columns={'Review_text':'Review'},inplace=True)
# <ipython-input-49-4c5f28534bb9>:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   amazondata2.rename(columns={'Review_Header':'Review'},inplace=True)

# %%
amazondata1.dropna(inplace=True)
amazondata2.dropna(inplace=True)
# Out:
# <ipython-input-50-430114bb11e7>:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   amazondata1.dropna(inplace=True)
# <ipython-input-50-430114bb11e7>:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   amazondata2.dropna(inplace=True)

# %%
amazondata1.reset_index(inplace=True)
amazondata2.reset_index(inplace=True)

# %%
amazondata1=amazondata1[['Category','Review','Rating']]
amazondata2=amazondata2[['Category','Review','Rating']]

# %%
amazondata1.to_csv('/content/drive/MyDrive/deeplearning/processed_rating/amazondata1.csv')
amazondata2.to_csv('/content/drive/MyDrive/deeplearning/processed_rating/amazondata2.csv')

# %%
amazon2=pd.read_csv('/content/drive/MyDrive/deeplearning/datasets_for_rating/Labeled-Amazon-Reviews-Dataset.csv')

# %%
amazon2
# Out:
#                                                   Name  Price  Availability  \
# 0    BIC Wite-Out Brand EZ Correct Correction Tape,...     17  Out of Stock
# 1    BIC Wite-Out Brand EZ Correct Correction Tape,...     17  Out of Stock
# 2    BIC Wite-Out Brand EZ Correct Correction Tape,...     17  Out of Stock
# 3    BIC Wite-Out Brand EZ Correct Correction Tape,...     17  Out of Stock
# 4    BIC Wite-Out Brand EZ Correct Correction Tape,...     17  Out of Stock
# ..                                                 ...    ...           ...
# 311    Under Armour Women's Ignite Select Slide Sandal     29      In Stock
# 312    Under Armour Women's Ignite Select Slide Sandal     29      In Stock
# 313    Under Armour Women's Ignite Select Slide Sandal     29      In Stock
# 314    Under Armour Women's Ignite Select Slide Sandal     29      In Stock
# 315    Under Armour Women's Ignite Select Slide Sandal     29      In Stock
#
#                             Brand  \
# ...

# %%
otheramazondata=amazon2[['Category','Review','Star']]

# %%
otheramazondata=otheramazondata.dropna()

# %%
otheramazondata.reset_index(inplace=True)

# %%
otheramazondata=otheramazondata[['Category','Review','Star']]

# %%
otheramazondata['Category'] = "A product in the category of "+otheramazondata['Category']
otheramazondata['Star']=pd.to_numeric(otheramazondata['Star'].str.get(i=0))

# %%
otheramazondata['Star']=otheramazondata['Star']*2
otheramazondata
# Out:
#                                               Category  \
# 0         A product in the category of Office Products
# 1         A product in the category of Office Products
# 2         A product in the category of Office Products
# 3         A product in the category of Office Products
# 4         A product in the category of Office Products
# ..                                                 ...
# 246  A product in the category of Clothing, Shoes &...
# 247  A product in the category of Clothing, Shoes &...
# 248  A product in the category of Clothing, Shoes &...
# 249  A product in the category of Clothing, Shoes &...
# 250  A product in the category of Clothing, Shoes &...
#
#                                                 Review  Star
# 0    frustrating because they sometimes get screwed...    10
# 1    I love these! They are super easy to use, ther...    10
# 2                   not the best quality, but it works    10
# ...

# %%
otheramazondata.rename(columns={'Star':'Rating'},inplace=True)

# %%
otheramazondata
# Out:
#                                               Category  \
# 0         A product in the category of Office Products
# 1         A product in the category of Office Products
# 2         A product in the category of Office Products
# 3         A product in the category of Office Products
# 4         A product in the category of Office Products
# ..                                                 ...
# 246  A product in the category of Clothing, Shoes &...
# 247  A product in the category of Clothing, Shoes &...
# 248  A product in the category of Clothing, Shoes &...
# 249  A product in the category of Clothing, Shoes &...
# 250  A product in the category of Clothing, Shoes &...
#
#                                                 Review  Rating
# 0    frustrating because they sometimes get screwed...      10
# 1    I love these! They are super easy to use, ther...      10
# 2                   not the best quality, but it works      10
# ...

# %%
otheramazondata.dropna(inplace=True)

# %%
otheramazondata
# Out:
#                                               Category  \
# 0         A product in the category of Office Products
# 1         A product in the category of Office Products
# 2         A product in the category of Office Products
# 3         A product in the category of Office Products
# 4         A product in the category of Office Products
# ..                                                 ...
# 246  A product in the category of Clothing, Shoes &...
# 247  A product in the category of Clothing, Shoes &...
# 248  A product in the category of Clothing, Shoes &...
# 249  A product in the category of Clothing, Shoes &...
# 250  A product in the category of Clothing, Shoes &...
#
#                                                 Review  Rating
# 0    frustrating because they sometimes get screwed...      10
# 1    I love these! They are super easy to use, ther...      10
# 2                   not the best quality, but it works      10
# ...

# %%
otheramazondata.to_csv('/content/drive/MyDrive/deeplearning/processed_rating/otheramazondata.csv')

# %%
corps=pd.read_csv('/content/drive/MyDrive/deeplearning/datasets_for_rating/trustpilot_reviews_2005.csv')

# %%
corps
# Out:
#                   category                    company  \
# 0           Animals & Pets  ruffandtumbledogcoats.com
# 1           Animals & Pets  ruffandtumbledogcoats.com
# 2           Animals & Pets  ruffandtumbledogcoats.com
# 3           Animals & Pets  ruffandtumbledogcoats.com
# 4           Animals & Pets  ruffandtumbledogcoats.com
# ...                    ...                        ...
# 123176  Media & Publishing              rarewaves.com
# 123177  Media & Publishing              rarewaves.com
# 123178  Media & Publishing              rarewaves.com
# 123179  Media & Publishing              rarewaves.com
# 123180  Media & Publishing              rarewaves.com
#
#                                               description  \
# 0       At Ruff and Tumble we are proud to be the mark...
# 1       At Ruff and Tumble we are proud to be the mark...
# 2       At Ruff and Tumble we are proud to be the mark...
# 3       At Ruff and Tumble we are proud to be the mark...
# ...

# %%
corpsdata1=corps[['category','review','stars']]
corpsdata2=corps[['category','title','stars']]

# %%
corpsdata2
# Out:
#                   category                                     title  stars
# 0           Animals & Pets   Great quality dog drying robe although…      5
# 1           Animals & Pets                     Really prompt service      5
# 2           Animals & Pets                                Life saver      5
# 3           Animals & Pets                           Brilliant coats      5
# 4           Animals & Pets                Great company and products      5
# ...                    ...                                       ...    ...
# 123176  Media & Publishing  Still haven't received my purchase even…      1
# 123177  Media & Publishing        Ordered 10 days ago.....not a peep      1
# 123178  Media & Publishing                      Bad first experience      1
# 123179  Media & Publishing      Waiting .....2 mths now..never again      1
# 123180  Media & Publishing        Avoid this company like the plague      1
#
# [123181 rows x 3 columns]

# %%
corpsdata1['category'] = "A company's services or products in the "+corpsdata1['category'].str.replace('&','and')+" industries"
corpsdata1['stars']=corpsdata1['stars']*2
corpsdata2['category'] = "A company's services or products in the "+corpsdata2['category'].str.replace('&','and')+" industries"
corpsdata2['stars']=corpsdata2['stars']*2
# Out:
# <ipython-input-71-324f4b223354>:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   corpsdata1['category'] = "A company's services or products in the "+corpsdata1['category'].str.replace('&','and')+" industries"
# <ipython-input-71-324f4b223354>:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   corpsdata1['stars']=corpsdata1['stars']*2
# <ipython-input-71-324f4b223354>:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# ...

# %%
corpsdata1
# Out:
#                                                  category  \
# 0       A company's services or products in the Animal...
# 1       A company's services or products in the Animal...
# 2       A company's services or products in the Animal...
# 3       A company's services or products in the Animal...
# 4       A company's services or products in the Animal...
# ...                                                   ...
# 123176  A company's services or products in the Media ...
# 123177  A company's services or products in the Media ...
# 123178  A company's services or products in the Media ...
# 123179  A company's services or products in the Media ...
# 123180  A company's services or products in the Media ...
#
#                                                    review  stars
# 0       Great quality dog drying robe although had to ...     10
# 1       Really prompt service, The sofa covers have no...     10
# 2       I’ve purchased first of those coats in May2020...     10
# ...

# %%
corpsdata1.rename(columns={'category':'Category','review':'Review','stars':'Rating'},inplace=True)
corpsdata2.rename(columns={'category':'Category','review':'Review','stars':'Rating'},inplace=True)
# Out:
# <ipython-input-73-6646d9351578>:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   corpsdata1.rename(columns={'category':'Category','review':'Review','stars':'Rating'},inplace=True)
# <ipython-input-73-6646d9351578>:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   corpsdata2.rename(columns={'category':'Category','review':'Review','stars':'Rating'},inplace=True)

# %%
corpsdata1.dropna(inplace=True)
corpsdata2.dropna(inplace=True)
# Out:
# <ipython-input-74-3352c653e57d>:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   corpsdata1.dropna(inplace=True)
# <ipython-input-74-3352c653e57d>:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   corpsdata2.dropna(inplace=True)

# %%
corpsdata1
# Out:
#                                                  Category  \
# 0       A company's services or products in the Animal...
# 1       A company's services or products in the Animal...
# 2       A company's services or products in the Animal...
# 3       A company's services or products in the Animal...
# 4       A company's services or products in the Animal...
# ...                                                   ...
# 123176  A company's services or products in the Media ...
# 123177  A company's services or products in the Media ...
# 123178  A company's services or products in the Media ...
# 123179  A company's services or products in the Media ...
# 123180  A company's services or products in the Media ...
#
#                                                    Review  Rating
# 0       Great quality dog drying robe although had to ...      10
# 1       Really prompt service, The sofa covers have no...      10
# 2       I’ve purchased first of those coats in May2020...      10
# ...

# %%
corpsdata1.to_csv('/content/drive/MyDrive/deeplearning/processed_rating/corpsdata1.csv')
corpsdata2.to_csv('/content/drive/MyDrive/deeplearning/processed_rating/corpsdata2.csv')

# %%
agoda=pd.read_csv('/content/drive/MyDrive/deeplearning/datasets_for_rating/agoda_rand.csv')

# %%
agoda['Category']="Hostel"

# %%
agodadata1=agoda[['Main Review','Score','Category']]
agodadata2=agoda[['Detail','Score','Category']]

# %%
agodadata2
# Out:
#                                                  Detail  Score Category
# 0     It is not a party hostel yet very well accommo...    9.6   Hostel
# 1     True to its name, Little Charm Hanoi hostel is...   10.0   Hostel
# 2     It was a perfect place to stay when visiting H...   10.0   Hostel
# 3     It was my first time solo traveling and stayin...   10.0   Hostel
# 4     This is the best hostel of the entire Vietnam....   10.0   Hostel
# ...                                                 ...    ...      ...
# 1244                     Location is good, overall okay    7.6   Hostel
# 1245                                Everything was nice    9.6   Hostel
# 1246  Good location. Close to markets and restaurants.     6.0   Hostel
# 1247                                Everything is okay     6.8   Hostel
# 1248                                               Good    9.2   Hostel
#
# [1249 rows x 3 columns]

# %%
agodadata1.rename(columns={'Main Review':'Review','Score':'Rating'},inplace=True)
agodadata2.rename(columns={'Detail':'Review','Score':'Rating'},inplace=True)
# Out:
# <ipython-input-81-7e469886c93f>:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   agodadata1.rename(columns={'Main Review':'Review','Score':'Rating'},inplace=True)
# <ipython-input-81-7e469886c93f>:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   agodadata2.rename(columns={'Detail':'Review','Score':'Rating'},inplace=True)

# %%
agodadata1.dropna(inplace=True)
agodadata2.dropna(inplace=True)
# Out:
# <ipython-input-82-981e6be8ff6c>:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   agodadata1.dropna(inplace=True)
# <ipython-input-82-981e6be8ff6c>:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   agodadata2.dropna(inplace=True)

# %%
agodadata2
# Out:
#                                                  Review  Rating Category
# 0     It is not a party hostel yet very well accommo...     9.6   Hostel
# 1     True to its name, Little Charm Hanoi hostel is...    10.0   Hostel
# 2     It was a perfect place to stay when visiting H...    10.0   Hostel
# 3     It was my first time solo traveling and stayin...    10.0   Hostel
# 4     This is the best hostel of the entire Vietnam....    10.0   Hostel
# ...                                                 ...     ...      ...
# 1244                     Location is good, overall okay     7.6   Hostel
# 1245                                Everything was nice     9.6   Hostel
# 1246  Good location. Close to markets and restaurants.      6.0   Hostel
# 1247                                Everything is okay      6.8   Hostel
# 1248                                               Good     9.2   Hostel
#
# [1249 rows x 3 columns]

# %%
agodadata1.to_csv('/content/drive/MyDrive/deeplearning/processed_rating/agodadata1.csv')
agodadata2.to_csv('/content/drive/MyDrive/deeplearning/processed_rating/agodadata2.csv')

# %%
laptop=pd.read_csv('/content/drive/MyDrive/deeplearning/datasets_for_rating/laptops_dataset_final_600.csv')

# %%
laptop
# Out:
#                                             product_name  overall_rating  \
# 0      Apple MacBook AIR Apple M2 - (8 GB/256 GB SSD/...             4.7
# 1      Apple MacBook AIR Apple M2 - (8 GB/256 GB SSD/...             4.7
# 2      Apple MacBook AIR Apple M2 - (8 GB/256 GB SSD/...             4.7
# 3      Apple MacBook AIR Apple M2 - (8 GB/256 GB SSD/...             4.7
# 4      Apple MacBook AIR Apple M2 - (8 GB/256 GB SSD/...             4.7
# ...                                                  ...             ...
# 24108  MSI Modern 14 Intel Core i5 13th Gen 1335U - (...             4.3
# 24109  MSI Modern 14 Intel Core i5 13th Gen 1335U - (...             4.3
# 24110  MSI Modern 14 Intel Core i5 13th Gen 1335U - (...             4.3
# 24111  Lenovo IdeaPad 5 2-in-1 WUXGA IPS AMD Ryzen 7 ...             4.4
# 24112  Lenovo IdeaPad 5 2-in-1 WUXGA IPS AMD Ryzen 7 ...             4.4
#
#       no_ratings no_reviews  rating                          title  \
# ...

# %%
laptop['Category']="Laptop"

# %%
laptopdata1=laptop[['title','rating','Category']]
laptopdata2=laptop[['review','rating','Category']]

# %%
laptopdata1['rating']=laptopdata1['rating']*2
laptopdata2['rating']=laptopdata2['rating']*2
# Out:
# <ipython-input-89-b9e3ec32d7dc>:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   laptopdata1['rating']=laptopdata1['rating']*2
# <ipython-input-89-b9e3ec32d7dc>:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   laptopdata2['rating']=laptopdata2['rating']*2

# %%
laptopdata2
# Out:
#                                                   review  rating Category
# 0      Loved it, it's my first MacBook that I earned ...      10   Laptop
# 1      Battery lasted longer than my first relationsh...      10   Laptop
# 2      Such a great deal.. very happy with the perfor...      10   Laptop
# 3      Awesome build quality and very good display, b...       8   Laptop
# 4      When i ordered and came to know about seller r...      10   Laptop
# ...                                                  ...     ...      ...
# 24108  MSI Laptop is high performance and the best. c...      10   Laptop
# 24109                 Excellent performance best laptop.      10   Laptop
# 24110  Decent battery life. Exceptional build quality...       8   Laptop
# 24111  The product does not support facial recognitio...       6   Laptop
# 24112  DISPLAY IS A LET DOWN. But the lenovo Pen work...       8   Laptop
#
# [24113 rows x 3 columns]

# %%
laptopdata1.rename(columns={'title':'Review','rating':'Rating'},inplace=True)
laptopdata2.rename(columns={'review':'Review','rating':'Rating'},inplace=True)
# Out:
# <ipython-input-91-a3c247a89526>:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   laptopdata1.rename(columns={'title':'Review','rating':'Rating'},inplace=True)
# <ipython-input-91-a3c247a89526>:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   laptopdata2.rename(columns={'review':'Review','rating':'Rating'},inplace=True)

# %%
laptopdata1.dropna(inplace=True)
laptopdata2.dropna(inplace=True)
# Out:
# <ipython-input-92-efdfd5fae307>:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   laptopdata1.dropna(inplace=True)
# <ipython-input-92-efdfd5fae307>:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   laptopdata2.dropna(inplace=True)

# %%
laptopdata2
# Out:
#                                                   Review  Rating Category
# 0      Loved it, it's my first MacBook that I earned ...      10   Laptop
# 1      Battery lasted longer than my first relationsh...      10   Laptop
# 2      Such a great deal.. very happy with the perfor...      10   Laptop
# 3      Awesome build quality and very good display, b...       8   Laptop
# 4      When i ordered and came to know about seller r...      10   Laptop
# ...                                                  ...     ...      ...
# 24108  MSI Laptop is high performance and the best. c...      10   Laptop
# 24109                 Excellent performance best laptop.      10   Laptop
# 24110  Decent battery life. Exceptional build quality...       8   Laptop
# 24111  The product does not support facial recognitio...       6   Laptop
# 24112  DISPLAY IS A LET DOWN. But the lenovo Pen work...       8   Laptop
#
# [24113 rows x 3 columns]

# %%
laptopdata1.to_csv('/content/drive/MyDrive/deeplearning/processed_rating/laptopdata1.csv')
laptopdata2.to_csv('/content/drive/MyDrive/deeplearning/processed_rating/laptopdata2.csv')

# %%
ebay=pd.read_csv('/content/drive/MyDrive/deeplearning/datasets_for_rating/archive (3)/ebay_reviews.csv')

# %%
ebay
# Out:
#               category                                      review title  \
# 0             Headsets                          Wireless gaming headset
# 1             Headsets        Good for those with a big head, low budget
# 2             Headsets                     MezumiWireless Gaming Headset
# 3             Headsets                             HW- S2 great headset.
# 4             Headsets  BEST HEADPHONES I'VE PURCHASED IN MY ENTIRE LIFE
# ...                ...                                               ...
# 44751  Racks & Holders                                    Utensil holder
# 44752  Racks & Holders                                       Recommended
# 44753  Racks & Holders                                     cheap looking
# 44754  Racks & Holders                                                Ok
# 44755  Racks & Holders                                  Cooking utensils
#
#                                           review content  rating
# ...

# %%
ebaydata1=ebay[['review title','rating','category']]
ebaydata2=ebay[['review content','rating','category']]

# %%
ebaydata1['rating']=ebaydata1['rating']*2
ebaydata2['rating']=ebaydata2['rating']*2
# Out:
# <ipython-input-98-6f885946c00e>:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   ebaydata1['rating']=ebaydata1['rating']*2
# <ipython-input-98-6f885946c00e>:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   ebaydata2['rating']=ebaydata2['rating']*2

# %%
ebaydata2
# Out:
#                                           review content  rating  \
# 0      This gaming headset ticks all the boxes # look...      10
# 1      Easy setup, rated for 6 hours battery but mine...       6
# 2      I originally bought this wireless headset for ...      10
# 3      This is my 2nd Mezumi headset, It kills the fi...      10
# 4      This is probably the best headset I've purchas...      10
# ...                                                  ...     ...
# 44751              Reasonably priced but a little flimsy       6
# 44752                                       As described      10
# 44753                                      cheap looking       2
# 44754                                               Okay      10
# 44755                                          Are goodg       8
#
#               category
# 0             Headsets
# 1             Headsets
# 2             Headsets
# 3             Headsets
# 4             Headsets
# ...                ...
# ...

# %%
ebaydata1.rename(columns={'review title':'Review','rating':'Rating','category':'Category'},inplace=True)
ebaydata2.rename(columns={'review content':'Review','rating':'Rating','category':'Category'},inplace=True)
# Out:
# <ipython-input-100-0194177e19dd>:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   ebaydata1.rename(columns={'review title':'Review','rating':'Rating','category':'Category'},inplace=True)
# <ipython-input-100-0194177e19dd>:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   ebaydata2.rename(columns={'review content':'Review','rating':'Rating','category':'Category'},inplace=True)

# %%
ebaydata1.dropna(inplace=True)
ebaydata2.dropna(inplace=True)
# Out:
# <ipython-input-101-7c7fefeafe61>:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   ebaydata1.dropna(inplace=True)
# <ipython-input-101-7c7fefeafe61>:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   ebaydata2.dropna(inplace=True)

# %%
ebaydata2
# Out:
#                                                   Review  Rating  \
# 0      This gaming headset ticks all the boxes # look...      10
# 1      Easy setup, rated for 6 hours battery but mine...       6
# 2      I originally bought this wireless headset for ...      10
# 3      This is my 2nd Mezumi headset, It kills the fi...      10
# 4      This is probably the best headset I've purchas...      10
# ...                                                  ...     ...
# 44751              Reasonably priced but a little flimsy       6
# 44752                                       As described      10
# 44753                                      cheap looking       2
# 44754                                               Okay      10
# 44755                                          Are goodg       8
#
#               Category
# 0             Headsets
# 1             Headsets
# 2             Headsets
# 3             Headsets
# 4             Headsets
# ...                ...
# ...

# %%
ebaydata1.to_csv('/content/drive/MyDrive/deeplearning/processed_rating/ebaydata1.csv')
ebaydata2.to_csv('/content/drive/MyDrive/deeplearning/processed_rating/ebaydata2.csv')

# %%
ecom=pd.read_csv('/content/drive/MyDrive/deeplearning/datasets_for_rating/ecommerce-product-reviews-dataset/ecommerce_product_reviews_dataset.csv')

# %%
ecom
# Out:
#          product_id             product_title                category  \
# 0           4589130   Stainless Steel Blender          Home & Kitchen
# 1           4716121  Long-Wear Matte Lipstick                  Beauty
# 2           9640962       Electric Toothbrush  Health & Personal Care
# 3           4442583    Hydrating Facial Serum                  Beauty
# 4           9757659         LEGO Building Kit            Toys & Games
# ...             ...                       ...                     ...
# 3999995     9263650      Slim Fit Denim Jeans                 Fashion
# 3999996     9757659         LEGO Building Kit            Toys & Games
# 3999997     9263650      Slim Fit Denim Jeans                 Fashion
# 3999998     7686351        Hand Sanitizer Gel  Health & Personal Care
# 3999999     3523465                  Yoga Mat       Sports & Outdoors
#
#                                   review_text  rating sentiment
# ...

# %%
ecomdata=ecom[['product_title','review_text','rating']]

# %%
ecomdata['rating']=ecomdata['rating']*2
# Out:
# <ipython-input-107-58bb1fb25dea>:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   ecomdata['rating']=ecomdata['rating']*2

# %%
ecomdata
# Out:
#                     product_title                           review_text  \
# 0         Stainless Steel Blender    Fast shipping and great packaging.
# 1        Long-Wear Matte Lipstick  Highly recommend. Excellent quality.
# 2             Electric Toothbrush      Terrible experience, do not buy.
# 3          Hydrating Facial Serum      Does the job, but not impressed.
# 4               LEGO Building Kit                Exactly what I needed!
# ...                           ...                                   ...
# 3999995      Slim Fit Denim Jeans      Terrible experience, do not buy.
# 3999996         LEGO Building Kit      Terrible experience, do not buy.
# 3999997      Slim Fit Denim Jeans                 Well worth the price!
# 3999998        Hand Sanitizer Gel      Does the job, but not impressed.
# 3999999                  Yoga Mat         Not bad, but has some issues.
#
#          rating
# 0            10
# 1            10
# 2             2
# 3             8
# ...

# %%
ecomdata.rename(columns={'review_text':'Review','rating':'Rating','product_title':'Category'},inplace=True)
# Out:
# <ipython-input-109-c6e4705b243e>:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   ecomdata.rename(columns={'review_text':'Review','rating':'Rating','product_title':'Category'},inplace=True)

# %%
ecomdata.dropna(inplace=True)
# Out:
# <ipython-input-110-b72e88110c3c>:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   ecomdata.dropna(inplace=True)

# %%
ecomdata
# Out:
#                          Category                                Review  \
# 0         Stainless Steel Blender    Fast shipping and great packaging.
# 1        Long-Wear Matte Lipstick  Highly recommend. Excellent quality.
# 2             Electric Toothbrush      Terrible experience, do not buy.
# 3          Hydrating Facial Serum      Does the job, but not impressed.
# 4               LEGO Building Kit                Exactly what I needed!
# ...                           ...                                   ...
# 3999995      Slim Fit Denim Jeans      Terrible experience, do not buy.
# 3999996         LEGO Building Kit      Terrible experience, do not buy.
# 3999997      Slim Fit Denim Jeans                 Well worth the price!
# 3999998        Hand Sanitizer Gel      Does the job, but not impressed.
# 3999999                  Yoga Mat         Not bad, but has some issues.
#
#          Rating
# 0            10
# 1            10
# 2             2
# 3             8
# ...

# %%
ecomdata.to_csv('/content/drive/MyDrive/deeplearning/processed_rating/ecomdata.csv')

# %%
book=pd.read_csv('/content/drive/MyDrive/deeplearning/datasets_for_rating/archive (15)/Books_rating.csv')

# %%
book
# Out:
#                  Id                           Title  Price         User_id  \
# 0        1882931173  Its Only Art If Its Well Hung!    NaN   AVCGYZL8FQQTD
# 1        0826414346        Dr. Seuss: American Icon    NaN  A30TK6U7DNS82R
# 2        0826414346        Dr. Seuss: American Icon    NaN  A3UH4UZ4RSVO82
# 3        0826414346        Dr. Seuss: American Icon    NaN  A2MVUWT453QH61
# 4        0826414346        Dr. Seuss: American Icon    NaN  A22X4XUPKF66MR
# ...             ...                             ...    ...             ...
# 2999995  B000NSLVCU             The Idea of History    NaN             NaN
# 2999996  B000NSLVCU             The Idea of History    NaN  A1SMUB9ASL5L9Y
# 2999997  B000NSLVCU             The Idea of History    NaN  A2AQMEKZKK5EE4
# 2999998  B000NSLVCU             The Idea of History    NaN  A18SQGYBKS852K
# 2999999  B000NSLVCU             The Idea of History    NaN             NaN
#
# ...

# %%
bookm=pd.read_csv('/content/drive/MyDrive/deeplearning/datasets_for_rating/archive (15)/books_data.csv')

# %%
bookm
# Out:
#                                                     Title  \
# 0                          Its Only Art If Its Well Hung!
# 1                                Dr. Seuss: American Icon
# 2                   Wonderful Worship in Smaller Churches
# 3                           Whispers of the Wicked Saints
# 4       Nation Dance: Religion, Identity and Cultural ...
# ...                                                   ...
# 212399  The Orphan Of Ellis Island (Time Travel Advent...
# 212400                            Red Boots for Christmas
# 212401                                              Mamaw
# 212402                                  The Autograph Man
# 212403  Student's Solutions Manual for Johnson/Mowry's...
#
#                                               description  \
# 0                                                     NaN
# 1       Philip Nel takes a fascinating look into the k...
# 2       This resource includes twelve principles in un...
# ...

# %%
bookdata=pd.merge(left = book , right = bookm, how = "inner", on = "Title")

# %%
bookdata
# Out:
#                  Id                           Title  Price         User_id  \
# 0        1882931173  Its Only Art If Its Well Hung!    NaN   AVCGYZL8FQQTD
# 1        0826414346        Dr. Seuss: American Icon    NaN  A30TK6U7DNS82R
# 2        0826414346        Dr. Seuss: American Icon    NaN  A3UH4UZ4RSVO82
# 3        0826414346        Dr. Seuss: American Icon    NaN  A2MVUWT453QH61
# 4        0826414346        Dr. Seuss: American Icon    NaN  A22X4XUPKF66MR
# ...             ...                             ...    ...             ...
# 2999995  B000NSLVCU             The Idea of History    NaN             NaN
# 2999996  B000NSLVCU             The Idea of History    NaN  A1SMUB9ASL5L9Y
# 2999997  B000NSLVCU             The Idea of History    NaN  A2AQMEKZKK5EE4
# 2999998  B000NSLVCU             The Idea of History    NaN  A18SQGYBKS852K
# 2999999  B000NSLVCU             The Idea of History    NaN             NaN
#
# ...

# %%
bookdata['Category']=("A book in the genre of "+bookdata['categories'][0]).replace('[','')
bookdata['Category']=bookdata['Category'].str.replace(']','')
bookdata['rating']=bookdata['review/score']*2

# %%
bookdata
# Out:
#                  Id                           Title  Price         User_id  \
# 0        1882931173  Its Only Art If Its Well Hung!    NaN   AVCGYZL8FQQTD
# 1        0826414346        Dr. Seuss: American Icon    NaN  A30TK6U7DNS82R
# 2        0826414346        Dr. Seuss: American Icon    NaN  A3UH4UZ4RSVO82
# 3        0826414346        Dr. Seuss: American Icon    NaN  A2MVUWT453QH61
# 4        0826414346        Dr. Seuss: American Icon    NaN  A22X4XUPKF66MR
# ...             ...                             ...    ...             ...
# 2999995  B000NSLVCU             The Idea of History    NaN             NaN
# 2999996  B000NSLVCU             The Idea of History    NaN  A1SMUB9ASL5L9Y
# 2999997  B000NSLVCU             The Idea of History    NaN  A2AQMEKZKK5EE4
# 2999998  B000NSLVCU             The Idea of History    NaN  A18SQGYBKS852K
# 2999999  B000NSLVCU             The Idea of History    NaN             NaN
#
# ...

# %%
bookdata1=bookdata[['Category','review/text','rating']]
bookdata2=bookdata[['Category','review/summary','rating']]

# %%
bookdata2
# Out:
#                                                  Category  \
# 0        A book in the genre of 'Comics & Graphic Novels'
# 1        A book in the genre of 'Comics & Graphic Novels'
# 2        A book in the genre of 'Comics & Graphic Novels'
# 3        A book in the genre of 'Comics & Graphic Novels'
# 4        A book in the genre of 'Comics & Graphic Novels'
# ...                                                   ...
# 2999995  A book in the genre of 'Comics & Graphic Novels'
# 2999996  A book in the genre of 'Comics & Graphic Novels'
# 2999997  A book in the genre of 'Comics & Graphic Novels'
# 2999998  A book in the genre of 'Comics & Graphic Novels'
# 2999999  A book in the genre of 'Comics & Graphic Novels'
#
#                                             review/summary  rating
# 0                   Nice collection of Julie Strain images     8.0
# 1                                        Really Enjoyed It    10.0
# ...

# %%
bookdata1.rename(columns={'review/text':'Review','rating':'Rating'},inplace=True)
bookdata2.rename(columns={'review/summary':'Review','rating':'Rating'},inplace=True)
# Out:
# <ipython-input-120-167d639d5d57>:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   bookdata1.rename(columns={'review/text':'Review','rating':'Rating'},inplace=True)
# <ipython-input-120-167d639d5d57>:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   bookdata2.rename(columns={'review/summary':'Review','rating':'Rating'},inplace=True)

# %%
bookdata1.dropna(inplace=True)
bookdata2.dropna(inplace=True)
# Out:
# <ipython-input-121-f80fdde2a609>:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   bookdata1.dropna(inplace=True)
# <ipython-input-121-f80fdde2a609>:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   bookdata2.dropna(inplace=True)

# %%
bookdata1
# Out:
#                                                  Category  \
# 0        A book in the genre of 'Comics & Graphic Novels'
# 1        A book in the genre of 'Comics & Graphic Novels'
# 2        A book in the genre of 'Comics & Graphic Novels'
# 3        A book in the genre of 'Comics & Graphic Novels'
# 4        A book in the genre of 'Comics & Graphic Novels'
# ...                                                   ...
# 2999995  A book in the genre of 'Comics & Graphic Novels'
# 2999996  A book in the genre of 'Comics & Graphic Novels'
# 2999997  A book in the genre of 'Comics & Graphic Novels'
# 2999998  A book in the genre of 'Comics & Graphic Novels'
# 2999999  A book in the genre of 'Comics & Graphic Novels'
#
#                                                     Review  Rating
# 0        This is only for Julie Strain fans. It's a col...     8.0
# 1        I don't care much for Dr. Seuss but after read...    10.0
# ...

# %%
bookdata1.to_csv('/content/drive/MyDrive/deeplearning/processed_rating/bookdata1.csv')
bookdata2.to_csv('/content/drive/MyDrive/deeplearning/processed_rating/bookdata2.csv')

# %%
map1=pd.read_excel('/content/drive/MyDrive/deeplearning/datasets_for_rating/archive (9)/dataset_Google-Maps-Reviews-Scraper_2023-10-07_21-20-35-389.xlsx')
map2=pd.read_excel('/content/drive/MyDrive/deeplearning/datasets_for_rating/archive (9)/dataset_Google-Maps-Reviews-Scraper_2023-10-07_21-52-25-741.xlsx')
map3=pd.read_excel('/content/drive/MyDrive/deeplearning/datasets_for_rating/archive (9)/dataset_Google-Maps-Reviews-Scraper_2023-10-07_20-39-19-861.xlsx')
map4=pd.read_excel('/content/drive/MyDrive/deeplearning/datasets_for_rating/archive (9)/dataset_Google-Maps-Reviews-Scraper_2023-10-07_05-38-02-353.xlsx')
map5=pd.read_excel('/content/drive/MyDrive/deeplearning/datasets_for_rating/archive (9)/dataset_Google-Maps-Reviews-Scraper_2023-10-07_22-26-46-127.xlsx')

# %%
map=pd.concat([map1,map2,map3,map4,map5])

# %%
map
# Out:
#                               title       categoryName  \
# 0                    Gasthaus Tirol  German restaurant
# 1                    Gasthaus Tirol  German restaurant
# 2                    Gasthaus Tirol  German restaurant
# 3                    Gasthaus Tirol  German restaurant
# 4                    Gasthaus Tirol  German restaurant
# ...                             ...                ...
# 27700  WNB Factory - Wings & Burger         Restaurant
# 27701  WNB Factory - Wings & Burger         Restaurant
# 27702  WNB Factory - Wings & Burger         Restaurant
# 27703  WNB Factory - Wings & Burger         Restaurant
# 27704  WNB Factory - Wings & Burger         Restaurant
#
#                                 website  \
# 0      http://www.gasthaus-cumming.com/
# 1      http://www.gasthaus-cumming.com/
# 2      http://www.gasthaus-cumming.com/
# 3      http://www.gasthaus-cumming.com/
# 4      http://www.gasthaus-cumming.com/
# ...                                 ...
# ...

# %%
map=map.dropna()

# %%
map.reset_index(inplace=True)

# %%
map['rating']=map['stars']*2
# Out:
# <ipython-input-129-3c9f97e80362>:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   map['rating']=map['stars']*2

# %%
mapdata=map[['categoryName','rating','text']]

# %%
mapdata
# Out:
#             categoryName  rating  \
# 0      German restaurant    10.0
# 1      German restaurant    10.0
# 2      German restaurant    10.0
# 3      German restaurant    10.0
# 4      German restaurant     8.0
# ...                  ...     ...
# 79311         Restaurant     6.0
# 79312         Restaurant    10.0
# 79313         Restaurant    10.0
# 79314         Restaurant     6.0
# 79315         Restaurant    10.0
#
#                                                     text
# 0      What a wonderful place. The food is outstandin...
# 1      Amazing food, amazing staff, great beer select...
# 2      Café mit Schlag & Linzer Torte’ perfectly deli...
# 3      Food is excellent, always great service. Great...
# 4      We really enjoy the food here. Most is pretty ...
# ...                                                  ...
# 79311              Prices was s little to high out there
# 79312  Buen servicio muy ricas alas. Todo excelente y...
# ...

# %%
mapdata.rename(columns={'text':'Review','rating':'Rating','categoryName':'Category'},inplace=True)
# Out:
# <ipython-input-132-335b6a12f534>:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   mapdata.rename(columns={'text':'Review','rating':'Rating','categoryName':'Category'},inplace=True)

# %%
mapdata.dropna(inplace=True)
# Out:
# <ipython-input-133-cf727e78b080>:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   mapdata.dropna(inplace=True)

# %%
mapdata
# Out:
#                 Category  Rating  \
# 0      German restaurant    10.0
# 1      German restaurant    10.0
# 2      German restaurant    10.0
# 3      German restaurant    10.0
# 4      German restaurant     8.0
# ...                  ...     ...
# 79311         Restaurant     6.0
# 79312         Restaurant    10.0
# 79313         Restaurant    10.0
# 79314         Restaurant     6.0
# 79315         Restaurant    10.0
#
#                                                   Review
# 0      What a wonderful place. The food is outstandin...
# 1      Amazing food, amazing staff, great beer select...
# 2      Café mit Schlag & Linzer Torte’ perfectly deli...
# 3      Food is excellent, always great service. Great...
# 4      We really enjoy the food here. Most is pretty ...
# ...                                                  ...
# 79311              Prices was s little to high out there
# 79312  Buen servicio muy ricas alas. Todo excelente y...
# ...

# %%
mapdata.to_csv('/content/drive/MyDrive/deeplearning/processed_rating/mapdata.csv')
